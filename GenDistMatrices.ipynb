# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.getcwd())
os.chdir('/content/drive/My Drive/1006')
print(os.getcwd())
# Out:
# /content
# /content/drive/My Drive/1006

# %%
import pandas as pd
import numpy as np

# %%
# !pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=68034a26191f44aa9f3effe1237c448a8cc63d3533ec68501fb09af19da47782
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
import SelectIndices as si
# Out:
# importing Jupyter notebook from SelectIndices.ipynb
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/1006
# /content/drive/My Drive/1006
# Collecting fast-pytorch-kmeans
#   Downloading https://files.pythonhosted.org/packages/8c/f5/53c60cabaf84f95ad28eb45538c415cb044f90bbc52de3d2d4e90b8544f9/fast_pytorch_kmeans-0.1.6.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fast-pytorch-kmeans) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from fast-pytorch-kmeans) (1.8.0+cu101)
# Collecting pynvml
#   Downloading https://files.pythonhosted.org/packages/1b/1a/a25c143e1d2f873d67edf534b269d028dd3c20be69737cca56bf28911d02/pynvml-8.0.4-py3-none-any.whl
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->fast-pytorch-kmeans) (3.7.4.3)
# Building wheels for collected packages: fast-pytorch-kmeans
#   Building wheel for fast-pytorch-kmeans (setup.py) ... done
#   Created wheel for fast-pytorch-kmeans: filename=fast_pytorch_kmeans-0.1.6-cp37-none-any.whl size=7090 sha256=ef566a783e7fb1e612bfbf57b33fbc2550594d843bb666a48b916ffafefca17b
#   Stored in directory: /root/.cache/pip/wheels/bc/fc/2f/c4a16a2578591451fa497f455a1ec95431303421656c76c699
# Successfully built fast-pytorch-kmeans
# Installing collected packages: pynvml, fast-pytorch-kmeans
# Successfully installed fast-pytorch-kmeans-0.1.6 pynvml-8.0.4
# (80, 80)
# [16 63 55 53 78 18  2 43 40 74 59 21 56]

# %%
dataset_names = ['eo']
embed_types = ['cvec_pca16', 'cvec_nmf16', 'cvec_umap16', 'cvec_tsne16', 'bert', 'roberta', 'distil', 'glove6B', 'universal']

# %%
saved_list = []
for i in range(len(dataset_names)):
  for j in range(len(embed_types)):
    data = pd.read_csv(dataset_names[i] + '_' + embed_types[j] + '_train.csv', index_col=0)
    data = data.to_numpy()
    print(dataset_names[i] + '_' + embed_types[j] + '_train.csv')
    mu_list, sd_list = si.fit_norm(data)
    print('Creating kld matrix...')
    saved_list.append(si.get_kld_matrix(mu_list, sd_list, dataset_names[i], embed_types[j]))
print()
saved_list
# Out:
# eo_cvec_pca16_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_cvec_nmf16_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_cvec_umap16_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_cvec_tsne16_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_bert_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_roberta_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_distil_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_glove6B_train.csv
# Creating kld matrix...
# Saving kld matrix...
# eo_universal_train.csv
# Creating kld matrix...
# Saving kld matrix...
# ['eo_kld_cvec_pca16.npy',
#  'eo_kld_cvec_nmf16.npy',
#  'eo_kld_cvec_umap16.npy',
#  'eo_kld_cvec_tsne16.npy',
#  'eo_kld_bert.npy',
#  'eo_kld_roberta.npy',
#  'eo_kld_distil.npy',
#  'eo_kld_glove6B.npy',
#  'eo_kld_universal.npy']

# %%
saved_list = []
for i in range(len(dataset_names)):
  for j in range(len(embed_types)):
    data = pd.read_csv(dataset_names[i] + '_' + embed_types[j] + '_train.csv', index_col=0)
    data = data.to_numpy()
    print(dataset_names[i] + '_' + embed_types[j] + '_train.csv')
    print('Creating ks matrix...')
    saved_list.append(si.get_ks_matrix(data, dataset_names[i], embed_types[j]))
print()
saved_list

# %%
saved_list = []
for i in range(len(dataset_names)):
  for j in range(len(embed_types)):
    data = pd.read_csv(dataset_names[i] + '_' + embed_types[j] + '_train.csv', index_col=0)
    data = data.to_numpy()
    print(dataset_names[i] + '_' + embed_types[j] + '_train.csv')
    print('Creating cos matrix...')
    saved_list.append(si.get_cos_matrix(data, dataset_names[i], embed_types[j]))
print()
saved_list
# Out:
# eo_cvec_pca16_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_cvec_nmf16_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_cvec_umap16_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_cvec_tsne16_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_bert_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_roberta_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_distil_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_glove6B_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# eo_universal_train.csv
# Creating cos matrix...
# Saving cosine matrix...
# ['eo_cos_cvec_pca16.npy',
#  'eo_cos_cvec_nmf16.npy',
#  'eo_cos_cvec_umap16.npy',
#  'eo_cos_cvec_tsne16.npy',
#  'eo_cos_bert.npy',
#  'eo_cos_roberta.npy',
#  'eo_cos_distil.npy',
#  'eo_cos_glove6B.npy',
#  'eo_cos_universal.npy']
